# %%
import pandas as pd

df = pd.read_excel('draft2021.xlsx')
df.fillna(0)
# Out:
#     Rk  Pk   Tm                  Player                College  Yrs     G  \
# 0    1   1  DET         Cade Cunningham         Oklahoma State  1.0  64.0
# 1    2   2  HOU             Jalen Green                      0  1.0  67.0
# 2    3   3  CLE             Evan Mobley                    USC  1.0  69.0
# 3    4   4  TOR          Scottie Barnes          Florida State  1.0  74.0
# 4    5   5  ORL             Jalen Suggs                Gonzaga  1.0  48.0
# 5    6   6  OKC             Josh Giddey                      0  1.0  54.0
# 6    7   7  GSW        Jonathan Kuminga                      0  1.0  70.0
# 7    8   8  ORL            Franz Wagner               Michigan  1.0  79.0
# 8    9   9  SAC         Davion Mitchell                 Baylor  1.0  75.0
# 9   10  10  NOP         Ziaire Williams               Stanford  1.0  62.0
# 10  11  11  CHO         James Bouknight                  UConn  1.0  31.0
# 11  12  12  SAS            Joshua Primo                Alabama  1.0  50.0
# ...

# %%
df2 = df.describe()
df2.to_csv('Resumen Draft 2021.csv')

# %%
mejores = df.head(50).describe()
mejores.to_csv('Mejores.csv')

# %%
peores = df.tail(50).describe()
peores.to_csv('Peores.csv')

# %%
df3 = df.sort_values(by='PTS.1', ascending = False)
df3 = df3.reset_index()
df3 = df3[["Tm","Player", "Rk","TRB.1"]]
df3 = df3.fillna(0)
df3.to_csv('MejoresDraftRebotes.csv')
