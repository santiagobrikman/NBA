# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('regular.csv', encoding = 'latin-1')

# %%
tripleros = df.sort_values(by = '3P', ascending = False).head(5)
tripleros = tripleros.sort_values(by = '3P', ascending = True)
triplerosx = tripleros['Player']
triplerosy = tripleros['3P']

# %%
fig1 = plt.figure(1)
fig1.set_figheight(10)
fig1.set_figwidth(15)
fig1.set_facecolor('white')
ax = fig1.add_subplot(1,1,1)
plt.xlim(3, 4.7)
plt.title('Jugadores con más cantidad de triples - Temporada regular 2021-2022')
plt.xlabel('Triples por partido')
plt.ylabel('Jugador')
ax.barh(triplerosx, triplerosy, color = '#4CAF50')
plt.savefig("Tripleros.png")

# %%
edadpromedio = df['Age']
fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(15)
fig2.set_facecolor('white')
plt.title('Edad promedio de los jugadores de la NBA - Temporada regular 2021-2022')
plt.xlabel('Jugadores')
plt.ylabel('Edad')
plt.boxplot(edadpromedio)
plt.savefig("Edad Promedio.png")

# %%
df2 = df.groupby(['Tm']).mean()
df2 = df2.sort_values(by = 'Age', ascending=True).head(5).reset_index()
df2 = df2.sort_values(by = 'Age', ascending=False)

equipo = df2['Tm']
edadpromedio = df2['Age']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(23.50, 24.60)
fig2.set_facecolor('white')
plt.title('Equipos con jugadores de menor edad - Temporada regular 2021-2022')
plt.xlabel('Edad promedio')
plt.ylabel('Equipo')
plt.barh(equipo,edadpromedio,color = '#4CAF50')
plt.savefig("Equipos jovenes.png")

# %%
df2 = df.groupby(['Tm']).mean()
df2 = df2.sort_values(by = 'Age', ascending=False).head(5).reset_index()
df2 = df2.sort_values(by = 'Age', ascending=True)

equipo = df2['Tm']
edadpromedio = df2['Age']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(25, 30)
fig2.set_facecolor('white')
plt.title('Equipos con jugadores de mayor edad - Temporada regular 2021-2022')
plt.xlabel('Edad promedio')
plt.ylabel('Equipo')
plt.barh(equipo,edadpromedio,color = '#4CAF50')
plt.savefig("Equipos viejos.png")

# %%
#Posición con mejor conversión de triples

posicion_tripleros1 = df.groupby(['Pos']).mean().reset_index()
posicion_tripleros1 = posicion_tripleros1[['Pos', '3P%']].sort_values(by = '3P%', ascending = False)
posicion_tripleros1 = posicion_tripleros1.sort_values(by='3P%', ascending=True)


posicion = posicion_tripleros1['Pos']
conversiontriples = posicion_tripleros1['3P%']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(0.15, 0.40)
fig2.set_facecolor('white')
plt.title('Posiciones con mayor conversión de triples - Temporada regular 2021-2022')
plt.xlabel('Conversión de triples')
plt.ylabel('Posición')
plt.barh(posicion,conversiontriples,color = 'Purple')
plt.savefig("Posicion conversion triples.png")

# %%
#Posición con más triples anotados

posicion_tripleros1 = df.groupby(['Pos']).mean().reset_index()
posicion_tripleros1 = posicion_tripleros1[['Pos', '3P']].sort_values(by = '3P', ascending = False)
posicion_tripleros1 = posicion_tripleros1.sort_values(by='3P', ascending=True)


posicion = posicion_tripleros1['Pos']
triples_anotados = posicion_tripleros1['3P']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(0, 2.8)
fig2.set_facecolor('white')
plt.title('Posiciones con mas triples anotados por partido - Temporada regular 2021-2022')
plt.xlabel('Triples anotados')
plt.ylabel('Posición')
plt.barh(posicion,triples_anotados,color = 'Purple')
plt.savefig("Posicion triples anotados.png")

# %%
#Posición con más puntos anotados

posicion_tripleros1 = df.groupby(['Pos']).mean().reset_index()
posicion_tripleros1 = posicion_tripleros1[['Pos', 'FG']].sort_values(by = 'FG', ascending = False)
posicion_tripleros1 = posicion_tripleros1.sort_values(by='FG', ascending=True)


posicion = posicion_tripleros1['Pos']
puntos_anotados = posicion_tripleros1['FG']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(2, 7)
fig2.set_facecolor('white')
plt.title('Posiciones con mas puntos anotados por partido - Temporada regular 2021-2022')
plt.xlabel('Puntos anotados')
plt.ylabel('Posición')
plt.barh(posicion,puntos_anotados,color = 'Navy')
plt.savefig("Posicion puntos anotados.png")

# %%
#Posición con mejor conversión de puntos

posicion_tripleros1 = df.groupby(['Pos']).mean().reset_index()
posicion_tripleros1 = posicion_tripleros1[['Pos', 'FG%']].sort_values(by = 'FG%', ascending = False)
posicion_tripleros1 = posicion_tripleros1.sort_values(by='FG%', ascending=True)


posicion = posicion_tripleros1['Pos']
puntos_anotados = posicion_tripleros1['FG%']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(0.35, 0.55)
fig2.set_facecolor('white')
plt.title('Posiciones con mejor conversión de puntos - Temporada regular 2021-2022')
plt.xlabel('Conversión de puntos')
plt.ylabel('Posición')
plt.barh(posicion,puntos_anotados,color = 'Navy')
plt.savefig("Posicion conversion puntos.png")

# %%
#Equipos con mejor conversión

mejorequipo = df.groupby(['Tm']).mean()
mejorequipo = mejorequipo.sort_values(by='FG%', ascending=False).head(5).reset_index()
mejorequipo = mejorequipo.sort_values(by='FG%', ascending=True)

equipo = mejorequipo['Tm']
conversion = mejorequipo['FG%']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(0.44, 0.48)
fig2.set_facecolor('white')
plt.title('Equipos con mejor conversión de puntos - Temporada regular 2021-2022')
plt.xlabel('Conversión de puntos')
plt.ylabel('Equipo')
plt.barh(equipo,conversion,color = 'orange')
plt.savefig("Equipo mejor conversion puntos.png")

# %%
#Equipos con mejor conversión

mejorequipo = df.groupby(['Tm']).mean()
mejorequipo = mejorequipo.sort_values(by='3P%', ascending=False).head(5).reset_index()
mejorequipo = mejorequipo.sort_values(by='3P%', ascending=True)

equipo = mejorequipo['Tm']
conversion = mejorequipo['3P%']

fig2 = plt.figure(1)
fig2.set_figheight(10)
fig2.set_figwidth(8)
plt.xlim(0.3, 0.36)
fig2.set_facecolor('white')
plt.title('Equipos con mejor conversión de triples - Temporada regular 2021-2022')
plt.xlabel('Conversión de triples')
plt.ylabel('Equipo')
plt.barh(equipo,conversion,color = 'orange')
plt.savefig("Equipo mejor conversion triples.png")
